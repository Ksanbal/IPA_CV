# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# 구글 드라이브와 연동하는 방법 입니다. 
# Google File Drive Stream 접근을 허용해야 합니다.
from google.colab import auth
auth.authenticate_user()

# 구글 드라이브 mount 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# 1. 홈 디렉토리에 datasets 폴더 생성 후, 그 안에 cats_and_dogs_small 폴더를 생성 합니다.
# 2. cats_and_dogs_small 안에 train, test, validation 폴더가 위치 하도록 압축을 풉니다.
# %cd gdrive/My Drive/datasets/cats_and_dogs_small
# Out:
# /content/gdrive/My Drive/datasets/cats_and_dogs_small

# %%
# !ls
# Out:
# MyInceptionNet.h5   newvgg_catsdogs.h5	ThumbDB_190312.db  validation
# MyVGGNet_200521.h5  test		train

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/datasets/cats_and_dogs_small

# %%
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator

# 모든 이미지를 1/255로 스케일을 조정합니다
# (batch, height, width, channel)
# Numpy N-dims Array (60000, 28, 28, 1) batch_size = 4 --> (4, 28, 28, 1)
# 0 ~255 /255 -> 0 ~ 1
# Image Augmentation
train_datagen = ImageDataGenerator(rescale = 1./255, 
                                   shear_range = 0.2, 
                                   zoom_range = 0.2, 
                                   horizontal_flip = True)
# Batch_size = 4 -> (4, 28, 28, 1)
# Augmentation: Shear, Zoom, Flip

test_datagen = ImageDataGenerator(rescale=1./255)
# Augmentation X , Scale [0~1]

base_dir = '/content/gdrive/My Drive/datasets/cats_and_dogs_small'

train_dir = os.path.join(base_dir, 'train')
# '/content/gdrive/My Drive/datasets/cats_and_dogs_small/train'
test_dir  = os.path.join(base_dir, 'test')
# '/content/gdrive/My Drive/datasets/cats_and_dogs_small/test'
validation_dir = os.path.join(base_dir, 'validation')
# '/content/gdrive/My Drive/datasets/cats_and_dogs_small/validation'


train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(224, 224),
        batch_size=4,
        # binary_crossentropy 손실을 사용하기 때문에 이진 레이블이 필요합니다
        class_mode='categorical')
# Source (4, 224, 224, 3)
# Target (4, 2)

# Target index {'cats': 0, 'dogs': 1}
# [[1, 0]    --> cat
#  [0, 1]    --> dog
#  [1, 0]    --> cat
#  [1, 0]]   --> cat
# Binary 0 ~ 1
# Categorical [1, 0] == 0
#             [0, 1] == 1


validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(224, 224),
        batch_size=4,
        class_mode='categorical')

# source (4, 224, 224, 3)
# target (4, 2)
# Out:
# Using TensorFlow backend.
# Found 2000 images belonging to 2 classes.
# Found 1206 images belonging to 2 classes.

# %%
for data_batch, labels_batch in train_generator:
    print ('Batch size:', data_batch.shape)
    print ('Label size:', labels_batch.shape)
    break

# One-Hot encoding Example
# 2개 0, 1
# 0: [1, 0]
# 1: [0, 1]
# Out:
# Batch size: (4, 224, 224, 3)
# Label size: (4, 2)

# %%
print (train_generator.class_indices)
# Out:
# {'cats': 0, 'dogs': 1}

# %%
#  This code cell shows how to utilize VGG16 model by combining Dense layer at the end of the network 
from keras.layers import Input, Dense, GlobalAveragePooling2D, Flatten
from keras.models import Model

from keras.applications.vgg16 import VGG16
from keras import layers
from keras import models

VGGNet = VGG16()
VGGNet.summary()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 36s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
# We will not update VGG pre-trained model, only added Dense layers will be trained from the scratch
for layer in VGGNet.layers:
  layer.trainable = False
  
Feature_Flatten = VGGNet.get_layer('flatten').output

dense = Dense(256, name='encoding', activation='relu')(Feature_Flatten)
predictions = Dense(2, activation='softmax', name="prediction")(dense)

New_VGGmodel = Model(inputs=VGGNet.input, outputs=predictions)
New_VGGmodel.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

New_VGGmodel.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# encoding (Dense)             (None, 256)               6422784
# _________________________________________________________________
# prediction (Dense)           (None, 2)                 514
# =================================================================
# Total params: 21,137,986
# Trainable params: 6,423,298
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
history = New_VGGmodel.fit_generator(
    train_generator,
    # validation_data=validation_generator, 
    # validation_steps=5,
    # 20장 / batch_size 4 = 5
    steps_per_epoch=50,
    # 60장 / batch_size 4 = 15
    epochs=5
    # 전체 반복 횟수 입니다.
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/5
# 50/50 [==============================] - 152s 3s/step - loss: 3.0053 - accuracy: 0.6000
# Epoch 2/5
# 50/50 [==============================] - 149s 3s/step - loss: 1.3456 - accuracy: 0.7450
# Epoch 3/5
# 50/50 [==============================] - 168s 3s/step - loss: 1.1548 - accuracy: 0.7000
# Epoch 4/5
# 50/50 [==============================] - 150s 3s/step - loss: 0.8613 - accuracy: 0.7950
# Epoch 5/5
# 50/50 [==============================] - 140s 3s/step - loss: 0.5670 - accuracy: 0.8000

# %%
print (train_generator.class_indices)
# Out:
# {'cats': 0, 'dogs': 1}

# %%
pip install flickrapi
# Out:
# Collecting flickrapi
#   Downloading https://files.pythonhosted.org/packages/76/d7/291b7f0f02cf0f59460f7bcc15192905b4c61e13b9fb9263ee86b0a5f647/flickrapi-2.4.0-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.2.1 in /usr/local/lib/python3.6/dist-packages (from flickrapi) (2.23.0)
# Collecting requests-toolbelt>=0.3.1
#   Downloading https://files.pythonhosted.org/packages/60/ef/7681134338fc097acef8d9b2f8abe0458e4d87559c689a8c306d0957ece5/requests_toolbelt-0.9.1-py2.py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 2.7MB/s
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from flickrapi) (1.3.0)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from flickrapi) (1.12.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->flickrapi) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->flickrapi) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->flickrapi) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->flickrapi) (2020.4.5.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.4.0->flickrapi) (3.1.0)
# Installing collected packages: requests-toolbelt, flickrapi
# Successfully installed flickrapi-2.4.0 requests-toolbelt-0.9.1

# %%
from flickrapi import FlickrAPI

FLICKER_KEY = '505e8c2b05e8b5aa51766a43fc4bc7a7'
FLICKER_SECRET = '46b3ef2f43b04ac6'

flickr = FlickrAPI(FLICKER_KEY, FLICKER_SECRET, format='parsed-json')
extras='url_s'
cats = flickr.photos.search(text='puppy', per_page=5, extras=extras)
photos = cats['photos']

# %%
photos
# Out:
# {'page': 1,
#  'pages': 38558,
#  'perpage': 5,
#  'photo': [{'farm': 66,
#    'height_s': 240,
#    'id': '50044923033',
#    'isfamily': 0,
#    'isfriend': 0,
#    'ispublic': 1,
#    'owner': '187198841@N07',
#    'secret': '9d43ac4d53',
#    'server': '65535',
#    'title': 'Doggo Bloggo via Poop4U',
#    'url_s': 'https://live.staticflickr.com/65535/50044923033_9d43ac4d53_m.jpg',
#    'width_s': 180},
#   {'farm': 66,
#    'height_s': 240,
#    'id': '50044853158',
#    'isfamily': 0,
#    'isfriend': 0,
#    'ispublic': 1,
#    'owner': '79053826@N07',
#    'secret': '808f96a7bf',
#    'server': '65535',
#    'title': 'puppy 2',
#    'url_s': 'https://live.staticflickr.com/65535/50044853158_808f96a7bf_m.jpg',
#    'width_s': 180},
#   {'farm': 66,
#    'height_s': 240,
#    'id': '50045648482',
#    'isfamily': 0,
#    'isfriend': 0,
#    'ispublic': 1,
#    'owner': '75540416@N05',
#    'secret': '4eaeffba5b',
#    'server': '65535',
#    'title': 'Puppy',
#    'url_s': 'https://live.staticflickr.com/65535/50045648482_4eaeffba5b_m.jpg',
#    'width_s': 133},
#   {'farm': 66,
#    'height_s': 240,
#    'id': '50045648492',
#    'isfamily': 0,
#    'isfriend': 0,
#    'ispublic': 1,
#    'owner': '75540416@N05',
#    'secret': 'a71c65501d',
#    'server': '65535',
#    'title': 'Puppy',
#    'url_s': 'https://live.staticflickr.com/65535/50045648492_a71c65501d_m.jpg',
#    'width_s': 133},
#   {'farm': 66,
#    'height_s': 240,
#    'id': '50044827453',
#    'isfamily': 0,
#    'isfriend': 0,
#    'ispublic': 1,
#    'owner': '75540416@N05',
#    'secret': 'dbcb8a58dc',
#    'server': '65535',
#    'title': 'Puppy',
#    'url_s': 'https://live.staticflickr.com/65535/50044827453_dbcb8a58dc_m.jpg',
#    'width_s': 133}],
#  'total': '192786'}

# %%
# import the necessary packages
import numpy as np
import urllib
import cv2

def url_to_image(url):
  resp = urllib.request.urlopen(url)
  image = np.asarray(bytearray(resp.read()), dtype="uint8")
  image = cv2.imdecode(image, cv2.IMREAD_COLOR)

  return image

# %%
from google.colab.patches import cv2_imshow

image_original_url = photos['photo'][0]['url_s']

image_temp = url_to_image(image_original_url)
cv2_imshow(image_temp)
# Out:
# <PIL.Image.Image image mode=RGB size=180x240 at 0x7F066213B5C0>

# %%
image_original_url
# Out:
# 'https://live.staticflickr.com/65535/50044923033_9d43ac4d53_m.jpg'

# %%
# 4D-tensor(B, H, W, C) -> (1, 224, 224, 3)
image_temp.shape
# Out:
# (240, 180, 3)

# %%
resized_image = cv2.resize(image_temp, (224, 224))
print (resized_image.shape)
# Out:
# (224, 224, 3)

# %%
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F06620989E8>

# %%
resized_image = np.expand_dims(resized_image, axis=0)
print (resized_image.shape)
# Out:
# (1, 224, 224, 3)

# %%
result = New_VGGmodel.predict(resized_image)

# %%
result
# Out:
# array([[2.1228876e-11, 1.0000000e+00]], dtype=float32)

# %%
np.argmax(result)
# Out:
# 1

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/datasets/cats_and_dogs_small

# %%
New_VGGmodel.save('newvgg_puppy.h5')

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
loss = history.history['loss']

epochs = range(1, len(acc) + 1)

# ‘bo’는 파란색 점을 의미합니다
plt.plot(epochs, loss, 'bo', label='Training loss')
# ‘b’는 파란색 실선을 의미합니다
# plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
